# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Enrollment_Data.csv')

# %%
df.head()
# Out:
#    avg_income  CAMPUS_VISIT CAMPUS_VISIT_2 CONTACT_CODE1  Contact_Date  \
# 0         NaN             0              0           EML             1
# 1         NaN             0              0           SAT            12
# 2         NaN             0              0           C01            16
# 3         NaN             0              0           EML            11
# 4         NaN             0              0           TFL            28
#
#   Contact_Month  Contact_Year  distance  Target_Enroll ETHNICITY  ...  \
# 0           Sep          2012       NaN              0       NaN  ...
# 1           Feb          2014       NaN              0         N  ...
# 2           Jan          2015       NaN              0         C  ...
# 3           Mar          2015       NaN              0       NaN  ...
# 4           Mar          2015       NaN              0         B  ...
#
#    premiere  REFERRAL_CNTCTS  satscore SELF_INIT_CNTCTS  sex  \
# ...

# %%
df.isnull().sum()
# Out:
# avg_income             763
# CAMPUS_VISIT             0
# CAMPUS_VISIT_2           0
# CONTACT_CODE1            5
# Contact_Date             0
# Contact_Month            0
# Contact_Year             0
# distance               671
# Target_Enroll            0
# ETHNICITY              598
# hscrat                   0
# ID                       0
# init_span                0
# Instate                  0
# int1rat                  0
# int2rat                  0
# interest                 0
# IRSCHOOL               425
# LEVEL_YEAR               0
# mailq                    0
# premiere                 0
# REFERRAL_CNTCTS          0
# satscore              1887
# SELF_INIT_CNTCTS         0
# sex                    127
# SOLICITED_CNTCTS         0
# telecq                3055
# TERRITORY                0
# TOTAL_CONTACTS           0
# TRAVEL_INIT_CNTCTS       0
# dtype: int64

# %%
df
# Out:
#       avg_income  CAMPUS_VISIT CAMPUS_VISIT_2 CONTACT_CODE1  Contact_Date  \
# 0            NaN             0              0           EML             1
# 1            NaN             0              0           SAT            12
# 2            NaN             0              0           C01            16
# 3            NaN             0              0           EML            11
# 4            NaN             0              0           TFL            28
# ...          ...           ...            ...           ...           ...
# 5155     42857.0             0              0           CIP            19
# 5156     42857.0             0              0           CIP            15
# 5157     42857.0             0              0           CIP            21
# 5158     28829.0             0              0           LMI            18
# 5159         NaN             0              0           CIP            15
#
#      Contact_Month  Contact_Year    distance  Target_Enroll ETHNICITY  ...  \
# ...

# %%
df.isnull().sum()/5160*100
# Out:
# avg_income            14.786822
# CAMPUS_VISIT           0.000000
# CAMPUS_VISIT_2         0.000000
# CONTACT_CODE1          0.096899
# Contact_Date           0.000000
# Contact_Month          0.000000
# Contact_Year           0.000000
# distance              13.003876
# Target_Enroll          0.000000
# ETHNICITY             11.589147
# hscrat                 0.000000
# ID                     0.000000
# init_span              0.000000
# Instate                0.000000
# int1rat                0.000000
# int2rat                0.000000
# interest               0.000000
# IRSCHOOL               8.236434
# LEVEL_YEAR             0.000000
# mailq                  0.000000
# premiere               0.000000
# REFERRAL_CNTCTS        0.000000
# satscore              36.569767
# SELF_INIT_CNTCTS       0.000000
# sex                    2.461240
# SOLICITED_CNTCTS       0.000000
# telecq                59.205426
# TERRITORY              0.000000
# TOTAL_CONTACTS         0.000000
# ...

# %%
df.head()
# Out:
#    avg_income  CAMPUS_VISIT CAMPUS_VISIT_2 CONTACT_CODE1  Contact_Date  \
# 0         NaN             0              0           EML             1
# 1         NaN             0              0           SAT            12
# 2         NaN             0              0           C01            16
# 3         NaN             0              0           EML            11
# 4         NaN             0              0           TFL            28
#
#   Contact_Month  Contact_Year  distance  Target_Enroll ETHNICITY  ...  \
# 0           Sep          2012       NaN              0       NaN  ...
# 1           Feb          2014       NaN              0         N  ...
# 2           Jan          2015       NaN              0         C  ...
# 3           Mar          2015       NaN              0       NaN  ...
# 4           Mar          2015       NaN              0         B  ...
#
#    premiere  REFERRAL_CNTCTS  satscore SELF_INIT_CNTCTS  sex  \
# ...

# %%
df.drop('telecq',axis=1,inplace=True)

# %%
df.head()
# Out:
#    avg_income  CAMPUS_VISIT CAMPUS_VISIT_2 CONTACT_CODE1  Contact_Date  \
# 0         NaN             0              0           EML             1
# 1         NaN             0              0           SAT            12
# 2         NaN             0              0           C01            16
# 3         NaN             0              0           EML            11
# 4         NaN             0              0           TFL            28
#
#   Contact_Month  Contact_Year  distance  Target_Enroll ETHNICITY  ...  mailq  \
# 0           Sep          2012       NaN              0       NaN  ...      5
# 1           Feb          2014       NaN              0         N  ...      5
# 2           Jan          2015       NaN              0         C  ...      5
# 3           Mar          2015       NaN              0       NaN  ...      5
# 4           Mar          2015       NaN              0         B  ...      5
#
#    premiere  REFERRAL_CNTCTS satscore  SELF_INIT_CNTCTS  sex  \
# ...

# %%
df.drop('satscore',axis=1,inplace=True)

# %%
df.head()
# Out:
#    avg_income  CAMPUS_VISIT CAMPUS_VISIT_2 CONTACT_CODE1  Contact_Date  \
# 0         NaN             0              0           EML             1
# 1         NaN             0              0           SAT            12
# 2         NaN             0              0           C01            16
# 3         NaN             0              0           EML            11
# 4         NaN             0              0           TFL            28
#
#   Contact_Month  Contact_Year  distance  Target_Enroll ETHNICITY  ...  \
# 0           Sep          2012       NaN              0       NaN  ...
# 1           Feb          2014       NaN              0         N  ...
# 2           Jan          2015       NaN              0         C  ...
# 3           Mar          2015       NaN              0       NaN  ...
# 4           Mar          2015       NaN              0         B  ...
#
#    LEVEL_YEAR  mailq  premiere REFERRAL_CNTCTS  SELF_INIT_CNTCTS  sex  \
# ...

# %%
df.isnull().sum()/5160*100
# Out:
# avg_income            14.786822
# CAMPUS_VISIT           0.000000
# CAMPUS_VISIT_2         0.000000
# CONTACT_CODE1          0.096899
# Contact_Date           0.000000
# Contact_Month          0.000000
# Contact_Year           0.000000
# distance              13.003876
# Target_Enroll          0.000000
# ETHNICITY             11.589147
# hscrat                 0.000000
# ID                     0.000000
# init_span              0.000000
# Instate                0.000000
# int1rat                0.000000
# int2rat                0.000000
# interest               0.000000
# IRSCHOOL               8.236434
# LEVEL_YEAR             0.000000
# mailq                  0.000000
# premiere               0.000000
# REFERRAL_CNTCTS        0.000000
# SELF_INIT_CNTCTS       0.000000
# sex                    2.461240
# SOLICITED_CNTCTS       0.000000
# TERRITORY              0.000000
# TOTAL_CONTACTS         0.000000
# TRAVEL_INIT_CNTCTS     0.000000
# dtype: float64

# %%
df.describe()
# Out:
#           avg_income  CAMPUS_VISIT  Contact_Date  Contact_Year     distance  \
# count    4397.000000   5160.000000   5160.000000   5160.000000  4489.000000
# mean    53494.747100      0.150194     15.707558   2014.610659   318.016140
# std     23083.609393      0.374771      8.799722      0.723275   370.781848
# min      9783.000000      0.000000      1.000000   2010.000000     0.790555
# 25%     35568.000000      0.000000      7.000000   2014.000000   102.461358
# 50%     48627.000000      0.000000     16.000000   2015.000000   160.271705
# 75%     68458.000000      0.000000     23.000000   2015.000000   372.547430
# max    200001.000000      2.000000     31.000000   2016.000000  3882.192379
#
#        Target_Enroll       hscrat            ID    init_span      int1rat  \
# count    5160.000000  5160.000000   5160.000000  5160.000000  5160.000000
# mean        0.500000     0.088590  44615.840891    19.215891     0.045520
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5160 entries, 0 to 5159
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   avg_income          4397 non-null   float64
#  1   CAMPUS_VISIT        5160 non-null   int64
#  2   CAMPUS_VISIT_2      5160 non-null   object
#  3   CONTACT_CODE1       5155 non-null   object
#  4   Contact_Date        5160 non-null   int64
#  5   Contact_Month       5160 non-null   object
#  6   Contact_Year        5160 non-null   int64
#  7   distance            4489 non-null   float64
#  8   Target_Enroll       5160 non-null   int64
#  9   ETHNICITY           4562 non-null   object
#  10  hscrat              5160 non-null   float64
#  11  ID                  5160 non-null   int64
#  12  init_span           5160 non-null   int64
#  13  Instate             5160 non-null   object
#  14  int1rat             5160 non-null   float64
# ...
